# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#columns_to_drop = ['EIN', 'NAME']
c_t_drop = application_df.drop(['EIN', 'NAME'], axis=1)
c_t_drop.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
c_t_drop.nunique()

#or
# for column in c_t_drop.columns:
#     ctd_uniq_vals = c_t_drop[column].nunique()

#     print(column, ctd_uniq_vals)
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_type_cnts = c_t_drop['APPLICATION_TYPE'].value_counts()
app_type_cnts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`

# Chose my cutoff value
cutoff_value = 500

application_types_to_replace = app_type_cnts[app_type_cnts < cutoff_value].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_vlu_cnts = c_t_drop.CLASSIFICATION.value_counts()
classification_vlu_cnts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
# Filter value counts greater than one
classification_vlu_cnts[classification_vlu_cnts > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
classification_vlu_cnts[classification_vlu_cnts > 10]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#cutoff_value = 800

classifications_to_replace = classification_vlu_cnts[classification_vlu_cnts < 1000].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    c_t_drop['CLASSIFICATION'] = c_t_drop['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
c_t_drop['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
# Convert categorical data to numeric using one-hot encoding
df_cat_to_num = pd.get_dummies(c_t_drop)
df_cat_to_num
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  \
# 0           1      5000              1                     1
# 1           1    108590              1                     0
# 2           1      5000              0                     0
# 3           1      6692              1                     0
# 4           1    142590              1                     0
# ...       ...       ...            ...                   ...
# 34294       1      5000              0                     0
# 34295       1      5000              0                     0
# 34296       1      5000              0                     0
# 34297       1      5000              1                     0
# 34298       1  36500179              0                     0
#
#        APPLICATION_TYPE_T12  APPLICATION_TYPE_T13  APPLICATION_TYPE_T14  \
# 0                         0                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 34294                     0                     0                     0
# 34295                     0                     0                     0
# 34296                     0                     0                     0
# 34297                     0                     0                     0
# 34298                     0                     0                     0
#
#        APPLICATION_TYPE_T15  APPLICATION_TYPE_T17  APPLICATION_TYPE_T19  ...  \
# 0                         0                     0                     0  ...
# 1                         0                     0                     0  ...
# 2                         0                     0                     0  ...
# 3                         0                     0                     0  ...
# 4                         0                     0                     0  ...
# ...                     ...                   ...                   ...  ...
# 34294                     0                     0                     0  ...
# 34295                     0                     0                     0  ...
# 34296                     0                     0                     0  ...
# 34297                     0                     0                     0  ...
# 34298                     0                     0                     0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 52 columns]

# %%
#predict whether applicants will be successful if funded by Alphabet Soup.
# Split our preprocessed data into our features and target arrays. 21.Class2.Act6.getting_real_solution.ipynb
y = df_cat_to_num["IS_SUCCESSFUL"].values
X = df_cat_to_num.drop(["IS_SUCCESSFUL", "STATUS"], axis='columns').values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                4080
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 6,541
# Trainable params: 6,541
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5725 - accuracy: 0.7222
# Epoch 2/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5564 - accuracy: 0.7301
# Epoch 3/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5538 - accuracy: 0.7308
# Epoch 4/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5516 - accuracy: 0.7300
# Epoch 5/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5503 - accuracy: 0.7315
# Epoch 6/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5492 - accuracy: 0.7334
# Epoch 7/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5488 - accuracy: 0.7317
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5481 - accuracy: 0.7348
# Epoch 9/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5477 - accuracy: 0.7350
# Epoch 10/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5467 - accuracy: 0.7351
# Epoch 11/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5458 - accuracy: 0.7348
# Epoch 12/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5456 - accuracy: 0.7340
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5451 - accuracy: 0.7368
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5452 - accuracy: 0.7356
# Epoch 15/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5444 - accuracy: 0.7358
# Epoch 16/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5445 - accuracy: 0.7357
# Epoch 17/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5440 - accuracy: 0.7357
# Epoch 18/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5436 - accuracy: 0.7369
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5434 - accuracy: 0.7371
# Epoch 20/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5431 - accuracy: 0.7374
# Epoch 21/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5432 - accuracy: 0.7364
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5428 - accuracy: 0.7375
# Epoch 23/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5421 - accuracy: 0.7365
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5423 - accuracy: 0.7375
# Epoch 25/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5424 - accuracy: 0.7372
# Epoch 26/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5413 - accuracy: 0.7386
# Epoch 27/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5417 - accuracy: 0.7383
# Epoch 28/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5412 - accuracy: 0.7380
# Epoch 29/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5415 - accuracy: 0.7378
# Epoch 30/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5414 - accuracy: 0.7387
# Epoch 31/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5408 - accuracy: 0.7380
# Epoch 32/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5407 - accuracy: 0.7380
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5407 - accuracy: 0.7385
# Epoch 34/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5406 - accuracy: 0.7390
# Epoch 35/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5403 - accuracy: 0.7381
# Epoch 36/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5401 - accuracy: 0.7391
# Epoch 37/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5405 - accuracy: 0.7379
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5403 - accuracy: 0.7393
# Epoch 39/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5400 - accuracy: 0.7393
# Epoch 40/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5398 - accuracy: 0.7390
# Epoch 41/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5396 - accuracy: 0.7398
# Epoch 42/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5392 - accuracy: 0.7381
# Epoch 43/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5392 - accuracy: 0.7400
# Epoch 44/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5388 - accuracy: 0.7395
# Epoch 45/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5393 - accuracy: 0.7392
# Epoch 46/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5391 - accuracy: 0.7393
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5389 - accuracy: 0.7392
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5386 - accuracy: 0.7395
# Epoch 49/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5390 - accuracy: 0.7393
# Epoch 50/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5384 - accuracy: 0.7406
# Epoch 51/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5384 - accuracy: 0.7397
# Epoch 52/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5388 - accuracy: 0.7399
# Epoch 53/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5387 - accuracy: 0.7400
# Epoch 54/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5378 - accuracy: 0.7395
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7404
# Epoch 56/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7396
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5378 - accuracy: 0.7407
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5378 - accuracy: 0.7396
# Epoch 59/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5382 - accuracy: 0.7406
# Epoch 60/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5379 - accuracy: 0.7402
# Epoch 61/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5377 - accuracy: 0.7406
# Epoch 62/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5374 - accuracy: 0.7397
# Epoch 63/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5375 - accuracy: 0.7402
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5376 - accuracy: 0.7399
# Epoch 65/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5375 - accuracy: 0.7400
# Epoch 66/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5375 - accuracy: 0.7402
# Epoch 67/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5371 - accuracy: 0.7404
# Epoch 68/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5374 - accuracy: 0.7400
# Epoch 69/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5374 - accuracy: 0.7399
# Epoch 70/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5373 - accuracy: 0.7405
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5373 - accuracy: 0.7404
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5371 - accuracy: 0.7404
# Epoch 73/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5370 - accuracy: 0.7407
# Epoch 74/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5372 - accuracy: 0.7411
# Epoch 75/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5368 - accuracy: 0.7404
# Epoch 76/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5370 - accuracy: 0.7404
# Epoch 77/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5366 - accuracy: 0.7403
# Epoch 78/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5368 - accuracy: 0.7411
# Epoch 79/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5371 - accuracy: 0.7404
# Epoch 80/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5370 - accuracy: 0.7408
# Epoch 81/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5365 - accuracy: 0.7409
# Epoch 82/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5366 - accuracy: 0.7403
# Epoch 83/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5363 - accuracy: 0.7407
# Epoch 84/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5369 - accuracy: 0.7407
# Epoch 85/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5366 - accuracy: 0.7408
# Epoch 86/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5366 - accuracy: 0.7404
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7409
# Epoch 88/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5363 - accuracy: 0.7412
# Epoch 89/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5364 - accuracy: 0.7410
# Epoch 90/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5364 - accuracy: 0.7406
# Epoch 91/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5361 - accuracy: 0.7414
# Epoch 92/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5362 - accuracy: 0.7407
# Epoch 93/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5359 - accuracy: 0.7411
# Epoch 94/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5356 - accuracy: 0.7413
# Epoch 95/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5363 - accuracy: 0.7404
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5355 - accuracy: 0.7415
# Epoch 97/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7409
# Epoch 98/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5358 - accuracy: 0.7411
# Epoch 99/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5355 - accuracy: 0.7407
# Epoch 100/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5358 - accuracy: 0.7407

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5566 - accuracy: 0.7252 - 487ms/epoch - 2ms/step
# Loss: 0.556624174118042, Accuracy: 0.7252478003501892

# %%
# Export our model to HDF5 file
nn.save("AvisNNCharityhmwk.h5")

# %% [markdown]
# The purpose of this analysis was to predict whether applicants would be successful if funded by Alphabet Soup.
#
# RESULTS
# DATA PREPROCESSING:
# The target variables for my model included participating organizations' Application Types (T3-27037) and Classification (C1000-17326) specifically those with the highest value counts.
#
# The feature variables included AFFILIATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, and ASK_AMT. The variables I removed are IS_SUCCESSFUL and STATUS. because I want only for the model to make the prediction for applicants' successes if funded by Alphabet Soup.
#
# COMPLILING, TRAINING, EVALUATING THE MODEL
# The number of neurons selected in the first and second layers were selected randomly to observe for a high accuracy prediction rate. The more neurons involved, the more the model's performance can be enhanced.
# The Activation Functions ReLU and Sigmoid was used because they were cited as being the most commonly used in neural networks due to their fast learning and simplified output and usefulness in predicting probabilities, respectively. I was able to achieve a fairly targeted model performance with the use of two neuronal layers at 73%. To increase my model performances and I would use the same factors as above in addition an additional layer and use the sigmoid activation function for each of the layers.
#
# Overall: The model did fairly well. The output of an accuracy percentage of 73% predicting that specific applicant organizations with specific classifications and application types would be successful if funded by Alphabet Soup. Random Forest Model is recommended as a different model to use because it is another classification model but my current model was successful in giving me 73% accuracy prediction.
